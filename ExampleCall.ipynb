# %%
from CentralCode import *

x = time.time()
boundary = [[32.282663, -81.436383

],[32.134010, -80.731682],[31.537356, -81.139357

]]
name = "Savannah"
#Helper().mapcoordinate(boundary, name)
cleaned = Clean().fullycleanedf(boundary)
print("Final Time: ", time.time()-x)

fullycleaned = Clean().wordparse(cleaned, name,3, False)
unique = cleaned.drop_duplicates(subset=['Name', 'Label'])
markers = Helper().markers(boundary)
dictionary = Visualize().dictionary(fullycleaned, unique, 0.6, markers)
# Out:
# /Users/noah/Cobb-Microregion/CentralCode.py:119: DtypeWarning: Columns (4,5,6,10,13,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(StringIO(csv_data), sep=',')
# /Users/noah/Cobb-Microregion/CentralCode.py:119: DtypeWarning: Columns (4,5,6,7,8,9,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(StringIO(csv_data), sep=',')
# /Users/noah/Cobb-Microregion/CentralCode.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   namedways.drop('nodes', axis=1, inplace=True)
# /Users/noah/Cobb-Microregion/CentralCode.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   namedrelations.drop('members', axis=1, inplace=True)
# Final Time:  26.54643201828003
# /Users/noah/Cobb-Microregion/CentralCode.py:494: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask = df['Name'].str.contains(phrase)

# %%
from CentralCode import *
Visualize().visualizecities(dictionary, 3,6, markers)
Visualize().visualizecities(dictionary, 7,10, markers)
Visualize().visualizecities(dictionary, 11,16, markers)
Visualize().visualizecities(dictionary, 17,30, markers)
Visualize().visualizecities(dictionary, 31,10000, markers)
